# %%
# importing package
import matplotlib.pyplot as plt
import pandas as pd
  
# create data
df1 = pd.DataFrame([['S1', 1.5248, 1.5066], ['S2', 1.5066,1.7656 ], ['S3', 1.4998, 1.6488], ['S4', 1.1723, 1.7816]],
                  columns=['Tasks', 'ASM', 'MMH'])
# view data
print(df)
  
# plot grouped bar chart
df.plot(x='Tasks', y='MAE' 
        kind='bar',
        stacked=False,
        title='P1P2 MAE LSTM')

df2 = pd.DataFrame([['S1', 1.8857,2.3726 ], ['S2', 1.8791,2.3535 ], ['S3', 1.8737,2.2916 ], ['S4', 1.7175 , 2.3694]],
                  columns=['Tasks', 'ASM', 'MMH'], rows=['MAE'])



# view data
print(df)
  
# plot grouped bar chart
df.plot(x='Tasks', 
        kind='bar',
        stacked=False,
        title='P1P2 RMSE LSTM')

#BI-LSTM

df2 = pd.DataFrame([['S1', 0.9827,1.6588 ], ['S2', 0.6147,1.6922 ], ['S3', 0.8032,1.6680 ], ['S4', 0.9344 , 1.6538]],
                  columns=['Tasks', 'ASM', 'MMH'])



# view data
print(df)
  
# plot grouped bar chart
df.plot(x='Tasks', 
        kind='bar',
        stacked=False,
        title='P1P2 MAE B1-LSTM')

#GRU

df2 = pd.DataFrame([['S1', 1.3183,1.7361 ], ['S2', 1.3028,1.7206 ], ['S3', 1.2814, 1.7116 ], ['S4', 1.3369 , 1.7199]],
                  columns=['Tasks', 'ASM', 'MMH'])



# view data
print(df)
  
# plot grouped bar chart
df.plot(x='Tasks', 
        kind='bar',
        stacked=False,
        title='P1P2 MAE GRU')

#BI-GRU 

df2 = pd.DataFrame([['S1', 0.5037,1.7714 ], ['S2', 0.6147, 1.6768 ], ['S3', 0.5327, 1.6826 ], ['S4', 0.5044 , 1.6531]],
                  columns=['Tasks', 'ASM', 'MMH'])



# view data
print(df)
  
# plot grouped bar chart
df.plot(x='Tasks', 
        kind='bar',
        stacked=False,
        title='P1P2 MAE BI-GRU')
# Out:
#   Tasks     ASM     MMH
# 0    S1  1.5248  1.5066
# 1    S2  1.5066  1.7656
# 2    S3  1.4998  1.6488
# 3    S4  1.1723  1.7816
#   Tasks     ASM     MMH
# 0    S1  1.5248  1.5066
# 1    S2  1.5066  1.7656
# 2    S3  1.4998  1.6488
# 3    S4  1.1723  1.7816
#   Tasks     ASM     MMH
# 0    S1  1.5248  1.5066
# 1    S2  1.5066  1.7656
# 2    S3  1.4998  1.6488
# 3    S4  1.1723  1.7816
#   Tasks     ASM     MMH
# 0    S1  1.5248  1.5066
# 1    S2  1.5066  1.7656
# 2    S3  1.4998  1.6488
# 3    S4  1.1723  1.7816
#   Tasks     ASM     MMH
# 0    S1  1.5248  1.5066
# 1    S2  1.5066  1.7656
# 2    S3  1.4998  1.6488
# 3    S4  1.1723  1.7816

# %%
# importing package
import matplotlib.pyplot as plt
import pandas as pd
  
# MAE BiLSTM
df1 = pd.DataFrame([['S1', 0.9827,1.6588 ], ['S2', 0.6147,1.6922 ], ['S3', 0.8032,1.6680 ], ['S4', 0.9344 , 1.6538]],
                  columns=['Tasks', 'ASM', 'MMH'])
# view data
print(df1)
  
# plot grouped bar chart

df1.plot(x='Tasks', 
        kind='bar',
        stacked=False,
        title='P1P2 MAE BiLSTM')
plt.ylabel('MAE')

  
# RMSE BiLSTM
df2 = pd.DataFrame([['S1', 1.0921,2.2964 ], ['S2', 0.7078,2.3113 ], ['S3',0.8869,2.2987 ], ['S4', 1.0252 , 2.2941]],
                  columns=['Tasks', 'ASM', 'MMH'])
# view data
print(df2)
  
# plot grouped bar chart

df2.plot(x='Tasks', 
        kind='bar',
        stacked=False,
        title='P1P2 RMSE BiLSTM')
plt.ylabel('RMSE')
# Out:
#   Tasks     ASM     MMH
# 0    S1  0.9827  1.6588
# 1    S2  0.6147  1.6922
# 2    S3  0.8032  1.6680
# 3    S4  0.9344  1.6538
#   Tasks     ASM     MMH
# 0    S1  1.0921  2.2964
# 1    S2  0.7078  2.3113
# 2    S3  0.8869  2.2987
# 3    S4  1.0252  2.2941
# Text(0, 0.5, 'RMSE')
